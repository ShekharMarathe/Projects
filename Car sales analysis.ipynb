# %% [markdown]
# # Cars Data :-

# %%
#import the required libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("All_cars_dataset4 - Copy - Copy.csv")
df
# Out:
#                       Name     EMI       Price  Mileage(kmpl)  ENGINE (cc)  \
# 0            Porsche Macan  118950  69.98 Lakh          14.00       2995.0
# 1              Porsche 718  145262  85.46 Lakh           9.00       3995.0
# 2          Porsche Cayenne  202272   1.2 Crore           9.00       3996.0
# 3    Porsche Cayenne Coupe  224165  1.32 Crore          10.75       3996.0
# 4         Porsche Panamera  245599  1.44 Crore           8.00       4806.0
# ..                     ...     ...         ...            ...          ...
# 145           Renault Kwid    5407   3.18 Lakh          23.00        999.0
# 146         Renault Triber    9009   5.29 Lakh          18.00        999.0
# 147          Renault Kiger    9264   5.45 Lakh          12.00        999.0
# 148         Renault Duster   14601   9.73 Lakh          14.00       1498.0
# 149    Citroen C5 Aircross   50823   29.9 Lakh          18.00       1997.0
#
# ...

# %%
df.shape
# Out:
# (150, 21)

# %%
df.columns.values
# Out:
# array(['Name', 'EMI', 'Price', 'Mileage(kmpl)', 'ENGINE (cc)',
#        'Fuel_Type', 'TRANSMISSION', 'Length (mm)', 'Wheelbase (mm)',
#        'Boot Space (L)', 'Width (mm)', 'Turning Radius (m)',
#        'Fuel Capacity (L)', 'Height (mm)', 'Ground Clearance (mm)',
#        'Seating Capacity', 'Displacement (cc)', 'Peak Power',
#        'Peak Torque', 'Color Varients', 'Top_Speed'], dtype=object)

# %%
df.head()
# Out:
#                     Name     EMI       Price  Mileage(kmpl)  ENGINE (cc)  \
# 0          Porsche Macan  118950  69.98 Lakh          14.00       2995.0
# 1            Porsche 718  145262  85.46 Lakh           9.00       3995.0
# 2        Porsche Cayenne  202272   1.2 Crore           9.00       3996.0
# 3  Porsche Cayenne Coupe  224165  1.32 Crore          10.75       3996.0
# 4       Porsche Panamera  245599  1.44 Crore           8.00       4806.0
#
#   Fuel_Type TRANSMISSION  Length (mm) Wheelbase (mm) Boot Space (L)  ...  \
# 0    Petrol   Automatic          4696           2807            954  ...
# 1    Petrol   Automatic          4379           2475            127  ...
# 2       CNG   Automatic          4918           2895            645  ...
# 3    Petrol   Automatic          4931           2895            625  ...
# 4    Petrol   Automatic          5049           2950            500  ...
#
#    Turning Radius (m) Fuel Capacity (L) Height (mm)  Ground Clearance (mm)  \
# ...

# %%
df.dtypes
# Out:
# Name                      object
# EMI                        int64
# Price                     object
# Mileage(kmpl)            float64
# ENGINE (cc)              float64
# Fuel_Type                 object
# TRANSMISSION              object
# Length (mm)                int64
# Wheelbase (mm)            object
# Boot Space (L)            object
# Width (mm)                 int64
# Turning Radius (m)        object
# Fuel Capacity (L)         object
# Height (mm)                int64
# Ground Clearance (mm)     object
# Seating Capacity          object
# Displacement (cc)         object
# Peak Power                object
# Peak Torque               object
# Color Varients             int64
# Top_Speed                 object
# dtype: object

# %%
df.describe()
# Out:
#                 EMI  Mileage(kmpl)  ENGINE (cc)  Length (mm)   Width (mm)  \
# count  1.500000e+02     150.000000   144.000000   150.000000   150.000000
# mean   1.614732e+05      13.746200  2670.506944  4595.160000  1868.626667
# std    2.349283e+05       3.874834  1397.672201   444.256291   125.343263
# min    5.407000e+03       6.000000   999.000000  3435.000000  1574.000000
# 25%    1.897125e+04      11.000000  1498.000000  4315.750000  1800.000000
# 50%    8.498900e+04      14.000000  1998.000000  4659.500000  1864.500000
# 75%    1.795102e+05      16.975000  3113.250000  4935.750000  1936.000000
# max    1.614776e+06      23.000000  6749.000000  5770.000000  2222.000000
#
#        Height (mm)  Color Varients
# count    150.00000      150.000000
# mean    1576.30000       17.486667
# std      164.89532       10.994652
# min     1165.00000        1.000000
# 25%     1457.00000       11.000000
# 50%     1558.50000       14.000000
# 75%     1677.50000       22.000000
# ...

# %% [markdown]
# 1.75% cars gives the mileage less than 17 kmpl.
#
# 2.avg of all cars mileage is 13 kmpl.
#
# 3.maximum milage of car is 23 kmpl.
#
# 4.avg length of cars is 4595mm. amd width 1868mm.

# %%
df["TRANSMISSION"].unique()
# Out:
# array(['Automatic ', 'Manual ', 'Manual'], dtype=object)

# %%
df['TRANSMISSION'] = df['TRANSMISSION'].str.strip().str.lower()

# %%
df['TRANSMISSION'] = df['TRANSMISSION'].replace(['manual', 'automatic'], ['manual', 'automatic'])

# %%
df["TRANSMISSION"].unique()
# Out:
# array(['automatic', 'manual'], dtype=object)

# %% [markdown]
# # problem satatement:-
# 1.which of the transmission type & fule type cars are more  purchase buy customers.
#
# 2.And reason behind it.

# %%
df['TRANSMISSION'].value_counts().plot( kind = "barh",figsize=(8, 6))
plt.xlabel("Count", labelpad=15)
plt.ylabel("TRANSMISSION", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
df['TRANSMISSION'].value_counts()
# Out:
# TRANSMISSION
# Automatic     104
# Manual         45
# Manual          1
# Name: count, dtype: int64

# %%
100*df['TRANSMISSION'].value_counts()/len(df['TRANSMISSION'])
# Out:
# TRANSMISSION
# Automatic     69.333333
# Manual        30.000000
# Manual         0.666667
# Name: count, dtype: float64

# %% [markdown]
# 1.70% of cars buy with Automatic transmission.
#
# 2.only 30% of cars is buy with the manual trasmission.

# %% [markdown]
# # Data exploration:-

# %%
sns.barplot(x='Fuel_Type', y='Mileage(kmpl)', data=df)
plt.show()

# %% [markdown]
# 1.as we can see in the plot mileage of CNG+Petrol fule type car having more than diesel and petrol fule type cars.

# %%
sns.countplot(data = df, x = "Fuel_Type", hue = "TRANSMISSION")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %% [markdown]
# 1.mileage of CNG+petrol is more, Despite of that Here we see that fule type with petrol and automatic transmission are likely more purchase by customers So we have to analyse the data with other features.

# %%
Heat= pd.crosstab(df['Fuel_Type'], df['Peak Torque'])
plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Heatmap of Fuel_type vs Torque')
plt.xlabel('Peak Torque')
plt.ylabel('Fuel_Type')
plt.show()

# %%
Heat = pd.crosstab(df['Fuel_Type'], df['Peak Power'])
plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Heatmap of fule type vs power')
plt.xlabel('Peak Power')
plt.ylabel('Fuel_Type')
plt.show()

# %% [markdown]
# 1.Insight: By observing above both heatmap, we can say that Torque and power of Petrol Fule type is more as compair to other fule types. this is the main reasion behind purchesing cars with Petrol fule type.

# %%
sns.scatterplot(x="ENGINE (cc)",y = "Mileage(kmpl)",data = df,hue = "TRANSMISSION")
plt.show()

# %%
sns.lineplot (x="ENGINE (cc)",y="Mileage(kmpl)",data=df)        # data parameter is used to pass the data 
plt.show()

# %% [markdown]
# 1.above plot shows that as cc of Engine increases milage is decreases

# %%
sns.histplot(data=df,x = "ENGINE (cc)",kde = True)

plt.show()

# %% [markdown]
# 2Insight: as the cc increase milage decrease so there for count of more purches car are in 1000 to 2000 cc

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\marat\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df, x="Price", y="ENGINE (cc)")
# Out:
# <Axes: xlabel='Price', ylabel='ENGINE (cc)'>

# %% [markdown]
# As cc of Engine increases price also increase.there for most of the buyers in range of 1000 to 2000 cc.

# %%
sns.histplot(data=df,x = "ENGINE (cc)",kde = True)

plt.show()

# %%
sns.barplot(x = df.Price ,y = df.EMI)
plt.show()

# %% [markdown]
# plot shows here price increases at that time EMI also increases.

# %% [markdown]
# # CONCLUSION:-

# %% [markdown]
# 1.Due to high Power and high Torque of petrol fule type customers like to purches auto transsmission with petrol fule .
#
# 2.most of the buyers are in the range of 1000 to 2000 cc of engine.
#
# 3.milage of petrol +CNG fule type is more.
#
# 4.as price of cars increase EMI of cars also increase.
